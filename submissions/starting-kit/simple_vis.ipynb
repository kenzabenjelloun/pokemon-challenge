# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = '../../data/train/full_train_data.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary  Win_ratio
# 0     45           1      False   0.278195
# 1     60           1      False   0.380165
# 2     80           1      False   0.674242
# 3     80           1      False   0.560000
# 4     65           1      False   0.491071

# %%
plt.figure(figsize=(15, 8))
ax = sns.countplot(x="Type 1", hue="Legendary", data=df)

plt.xticks(rotation= 90)
plt.xlabel('Type 1')
plt.ylabel('Total ')
plt.title("Occurence avec Légendaire pour le Type 1")
# Out:
# Text(0.5, 1.0, 'Occurence avec Légendaire pour le Type 1')

# %%
plt.figure(figsize=(15, 8))
ax = sns.countplot(x="Type 2", hue="Legendary", data=df)

plt.xticks(rotation= 90)
plt.xlabel('Type 2')
plt.ylabel('Total ')
plt.title("Occurence avec Légendaire pour le Type 2")
# Out:
# Text(0.5, 1.0, 'Occurence avec Légendaire pour le Type 2')

# %%
# Carte de corrélation 
plt.figure(figsize=(10, 8))
plt.title('Corréalation des variables')


matrix = df.drop(columns=['#']).corr().round(2)
sns.heatmap(matrix, annot=True)
plt.show()

# %% [markdown]
# Les pokemons légendaire semblenta voir une Sp. Attack élévé

# %%
# Les 15 pokemons qui gagnent le plus 
df.iloc[df['Win_ratio'].sort_values(ascending=False).index[:15]]
# Out:
#        #                      Name   Type 1    Type 2   HP  Attack  Defense  \
# 154  155           Mega Aerodactyl     Rock    Flying   80     135       85
# 512  513                   Weavile     Dark       Ice   70     120       65
# 703  704    Tornadus Therian Forme   Flying       NaN   79     100       80
# 19    20             Mega Beedrill      Bug    Poison   65     150       40
# 153  154                Aerodactyl     Rock    Flying   80     105       65
# 476  477              Mega Lopunny   Normal  Fighting   65     136       94
# 726  727                  Greninja    Water      Dark   72      95       67
# 716  717  Meloetta Pirouette Forme   Normal  Fighting  100     128       90
# 164  165             Mega Mewtwo Y  Psychic       NaN  106     150       70
# 349  350             Mega Sharpedo    Water      Dark   70     140       70
# 248  249             Mega Houndoom     Dark      Fire   75      90       90
# 426  427             Mega Rayquaza   Dragon    Flying  105     180      100
# 23    24              Mega Pidgeot   Normal    Flying   83      80       80
# 275  276             Mega Sceptile    Grass    Dragon   70     110       75
# 551  552         Shaymin Sky Forme    Grass    Flying  100     103       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Win_ratio
# 154       70       95    150           1      False   0.984496
# 512       45       85    125           4      False   0.974790
# 703      110       90    121           5       True   0.968000
# 19        15       80    145           1      False   0.966387
# 153       60       75    130           1      False   0.964539
# 476       54       96    135           4      False   0.961240
# 726      103       71    122           6      False   0.960630
# 716       77       77    128           5      False   0.959350
# 164      194      120    140           1       True   0.952000
# 349      110       65    105           3      False   0.950000
# 248      140       90    115           2      False   0.948148
# 426      180      100    115           3       True   0.947761
# 23       135       80    121           1      False   0.944444
# 275      145       85    145           3      False   0.944444
# 551      120       75    127           4       True   0.940678

# %% [markdown]
# Quelques légendaires..

# %% [markdown]
# #### Les résultats des classifieurs de sklears sont "trop" bons sur la base de données brute.
# Voir quelles variables retirer

# %%
from sklearn.linear_model import LogisticRegression
