# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# %%
data = pd.read_csv("data/initial_data/pokemon.csv")
data
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
test_df = pd.DataFrame({})
test_df['Type 1'] = data['Type 1']
test_df['Type 2'] = data['Type 2']

# %%
test_df['Type 1'].values
# Out:
# array(['Grass', 'Grass', 'Grass', 'Grass', 'Fire', 'Fire', 'Fire', 'Fire',
#        'Fire', 'Water', 'Water', 'Water', 'Water', 'Bug', 'Bug', 'Bug',
#        'Bug', 'Bug', 'Bug', 'Bug', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Poison', 'Poison',
#        'Electric', 'Electric', 'Ground', 'Ground', 'Poison', 'Poison',
#        'Poison', 'Poison', 'Poison', 'Poison', 'Fairy', 'Fairy', 'Fire',
#        'Fire', 'Normal', 'Normal', 'Poison', 'Poison', 'Grass', 'Grass',
#        'Grass', 'Bug', 'Bug', 'Bug', 'Bug', 'Ground', 'Ground', 'Normal',
#        'Normal', 'Water', 'Water', 'Fighting', 'Fighting', 'Fire', 'Fire',
#        'Water', 'Water', 'Water', 'Psychic', 'Psychic', 'Psychic',
#        'Psychic', 'Fighting', 'Fighting', 'Fighting', 'Grass', 'Grass',
#        'Grass', 'Water', 'Water', 'Rock', 'Rock', 'Rock', 'Fire', 'Fire',
#        'Water', 'Water', 'Water', 'Electric', 'Electric', 'Normal',
# ...

# %%
data = test_df['Type 1'].values.reshape(-1, 1)

one_hot = OneHotEncoder(handle_unknown='ignore')
one_hot.fit(data)

# %%
type_two_data = test_df['Type 2'].values.reshape(-1, 1)
# Out:
# array([['Poison'],
#        ['Poison'],
#        ['Poison'],
#        ['Poison'],
#        [nan],
#        [nan],
#        ['Flying'],
#        ['Dragon'],
#        ['Flying'],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        ['Flying'],
#        ['Poison'],
#        ['Poison'],
#        ['Poison'],
#        ['Poison'],
#        ['Flying'],
#        ['Flying'],
#        ['Flying'],
#        ['Flying'],
#        [nan],
#        [nan],
#        ['Flying'],
#        ['Flying'],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        ['Ground'],
#        [nan],
#        [nan],
#        ['Ground'],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        ['Fairy'],
#        ['Fairy'],
#        ['Flying'],
#        ['Flying'],
#        ['Poison'],
#        ['Poison'],
#        ['Poison'],
#        ['Grass'],
#        ['Grass'],
# ...

# %%
res = pd.DataFrame({})

type_one_data = test_df['Type 1'].values.reshape(-1, 1)
type_two_data = test_df['Type 2'].values.reshape(-1, 1)
res['Type 1'] = one_hot.transform(type_one_data)
res['Type 2'] = one_hot.transform(type_two_data)

res
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 5
#       3 type_one_data = test_df['Type 1'].values.reshape(-1, 1)
#       4 type_two_data = test_df['Type 2'].values.reshape(-1, 1)
# ----> 5 res['Type 1'] = one_hot.transform(type_one_data)
#       6 res['Type 2'] = one_hot.transform(type_two_data)
#       8 res
#
# File ~/miniconda3/envs/ml_env/lib/python3.9/site-packages/pandas/core/frame.py:3978, in DataFrame.__setitem__(self, key, value)
#    3975     self._setitem_array([key], value)
#    3976 else:
#    3977     # set column
# -> 3978     self._set_item(key, value)
#
# File ~/miniconda3/envs/ml_env/lib/python3.9/site-packages/pandas/core/frame.py:4172, in DataFrame._set_item(self, key, value)
#    4162 def _set_item(self, key, value) -> None:
#    4163     """
#    4164     Add series to DataFrame in specified column.
#    4165
#    (...)
# ...

# %%
test_df['Type 1'].values.shape
# Out:
# (800,)

# %%
enc = OneHotEncoder(handle_unknown='ignore')
X = [['Male', 1], ['Female', 3], ['Female', 2]]
enc.fit(X)

len(enc.categories_)
# Out:
# 2
